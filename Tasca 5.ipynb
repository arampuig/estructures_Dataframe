# %%
- Exercici 1
Descarrega el data set Airlines Delay: Airline on-time statistics and delay causes i carrega’l a un pandas Dataframe. 
Explora les dades que conté, i queda’t únicament amb les columnes que consideris rellevants.

# %%
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

#Descartem les columnes d'any, mes, dia, origen i destí, ja que no les farem servir:
df = pd.read_csv('DelayedFlights.csv')
df.drop(['Year', 'Month', 'DayofMonth', 'DayOfWeek', 'Origin', 'Dest'], axis=1, inplace=True)
df
# Out:
#          Unnamed: 0  DepTime  CRSDepTime  ArrTime  CRSArrTime UniqueCarrier  FlightNum TailNum  ActualElapsedTime  CRSElapsedTime  AirTime  ArrDelay  DepDelay  Distance  TaxiIn  TaxiOut  Cancelled CancellationCode  Diverted  CarrierDelay  WeatherDelay  NASDelay  SecurityDelay  LateAircraftDelay
# 0                 0   2003.0        1955   2211.0        2225            WN        335  N712SW              128.0           150.0    116.0     -14.0       8.0       810     4.0      8.0          0                N         0           NaN           NaN       NaN            NaN                NaN
# 1                 1    754.0         735   1002.0        1000            WN       3231  N772SW              128.0           145.0    113.0       2.0      19.0       810     5.0     10.0          0                N         0           NaN           NaN       NaN            NaN                NaN
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1936758 entries, 0 to 1936757
# Data columns (total 30 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Unnamed: 0         int64
#  1   Year               int64
#  2   Month              int64
#  3   DayofMonth         int64
#  4   DayOfWeek          int64
#  5   DepTime            float64
#  6   CRSDepTime         int64
#  7   ArrTime            float64
#  8   CRSArrTime         int64
#  9   UniqueCarrier      object
#  10  FlightNum          int64
#  11  TailNum            object
#  12  ActualElapsedTime  float64
#  13  CRSElapsedTime     float64
#  14  AirTime            float64
#  15  ArrDelay           float64
#  16  DepDelay           float64
#  17  Origin             object
#  18  Dest               object
#  19  Distance           int64
#  20  TaxiIn             float64
#  21  TaxiOut            float64
#  22  Cancelled          int64
#  23  CancellationCode   object
# ...

# %%
df.drop(['Month'], axis = 1)
# Out:
#          Unnamed: 0  Year  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 0                 0  2008           3          4   2003.0        1955
# 1                 1  2008           3          4    754.0         735
# 2                 2  2008           3          4    628.0         620
# 3                 4  2008           3          4   1829.0        1755
# 4                 5  2008           3          4   1940.0        1915
# ...             ...   ...         ...        ...      ...         ...
# 1936753     7009710  2008          13          6   1250.0        1220
# 1936754     7009717  2008          13          6    657.0         600
# 1936755     7009718  2008          13          6   1007.0         847
# 1936756     7009726  2008          13          6   1251.0        1240
# 1936757     7009727  2008          13          6   1110.0        1103
#
#          ArrTime  CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  \
# ...

# %%
df.Dest.unique()

# %%
- Exercici 2
Fes un informe complet del data set:

# %%
-Resumeix estadísticament les columnes d’interès

# %%
df.describe().round(3)
# Out:
#         Unnamed: 0       Year        Month   DayofMonth    DayOfWeek      DepTime   CRSDepTime      ArrTime   CRSArrTime    FlightNum  ActualElapsedTime  CRSElapsedTime      AirTime     ArrDelay     DepDelay     Distance       TaxiIn      TaxiOut    Cancelled     Diverted  CarrierDelay  WeatherDelay     NASDelay  SecurityDelay  LateAircraftDelay
# count  1936758.000  1936758.0  1936758.000  1936758.000  1936758.000  1936758.000  1936758.000  1929648.000  1936758.000  1936758.000        1928371.000     1936560.000  1928371.000  1928371.000  1936758.000  1936758.000  1929648.000  1936303.000  1936758.000  1936758.000   1247488.000   1247488.000  1247488.000    1247488.000        1247488.000
# ...

# %%
-Troba quantes dades faltants hi ha per columna

# %%
#Dades faltants per cada columna
missing_values_count = df.isnull().sum()
missing_values_count
# Out:
# Unnamed: 0                0
# Year                      0
# Month                     0
# DayofMonth                0
# DayOfWeek                 0
# DepTime                   0
# CRSDepTime                0
# ArrTime                7110
# CRSArrTime                0
# UniqueCarrier             0
# FlightNum                 0
# TailNum                   5
# ActualElapsedTime      8387
# CRSElapsedTime          198
# AirTime                8387
# ArrDelay               8387
# DepDelay                  0
# Origin                    0
# Dest                      0
# Distance                  0
# TaxiIn                 7110
# TaxiOut                 455
# Cancelled                 0
# CancellationCode          0
# Diverted                  0
# CarrierDelay         689270
# WeatherDelay         689270
# NASDelay             689270
# SecurityDelay        689270
# LateAircraftDelay    689270
# medium_f_speed         8387
# medium_mph             8387
# Delayed                   0
# ...

# %%
-Crea columnes noves (velocitat mitjana del vol, si ha arribat tard o no...)

# %%
#Columna de la velocitat mitjana de vol en milles per hora
df['medium_mph'] = df['Distance']/ (df['AirTime']/60)
print(df['medium_mph'])
# Out:
# 0          418.965517
# 1          430.088496
# 2          406.578947
# 3          401.298701
# 4          474.482759
#               ...
# 1936753    453.000000
# 1936754    370.000000
# 1936755    338.852459
# 1936756    359.325843
# 1936757    504.230769
# Name: medium_mph, Length: 1936758, dtype: float64

# %%
#Columna dels vols endarrerits com a booleà, passat a 'Yes'/'No'
df['Delayed'] = df[['CarrierDelay','WeatherDelay', 'NASDelay','SecurityDelay','LateAircraftDelay']].sum(axis=1)>0
bool_cols = df.columns[df.dtypes == 'bool']
df[bool_cols] = df[bool_cols].replace({True: 'Yes', False: 'No'})

df
# Out:
#          Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  CRSArrTime UniqueCarrier  FlightNum TailNum  ActualElapsedTime  CRSElapsedTime  AirTime  ArrDelay  DepDelay Origin Dest  Distance  TaxiIn  TaxiOut  Cancelled CancellationCode  Diverted  CarrierDelay  WeatherDelay  NASDelay  SecurityDelay  LateAircraftDelay  medium_f_speed  medium_mph Delayed
# 0                 0  2008      1           3          4   2003.0        1955   2211.0        2225            WN        335  N712SW              128.0           150.0    116.0     -14.0       8.0    IAD  TPA       810     4.0      8.0          0                N         0           NaN           NaN       NaN            NaN                NaN      418.965517  418.965517      No
# ...

# %%
-Taula de les aerolínies amb més endarreriments acumulats

# %%
a = (df.groupby('UniqueCarrier')['Delayed'].count())
a.sort_values(ascending = False)
# Out:
# UniqueCarrier
# WN    377602
# AA    191865
# MQ    141920
# UA    141426
# OO    132433
# DL    114238
# XE    103663
# CO    100195
# US     98425
# EV     81877
# NW     79108
# FL     71284
# YV     67063
# B6     55315
# OH     52657
# 9E     51885
# AS     39293
# F9     28269
# HA      7490
# AQ       750
# Name: Delayed, dtype: int64

# %%
endarrerits = df[['UniqueCarrier', 'Delayed']]
endarrerits['Delayed'].groupby([endarrerits['UniqueCarrier'],endarrerits['Delayed'] == 'Yes']).count()
# Out:
# UniqueCarrier  Delayed
# 9E             False       16254
#                True        35631
# AA             False       59608
#                True       132257
# AQ             False         410
#                True          340
# AS             False       15281
#                True        24012
# B6             False       17083
#                True        38232
# CO             False       41237
#                True        58958
# DL             False       41986
#                True        72252
# EV             False       25096
#                True        56781
# F9             False       12329
#                True        15940
# FL             False       24293
#                True        46991
# HA             False        3165
#                True         4325
# MQ             False       44365
#                True        97555
# NW             False       24364
#                True        54744
# OH             False       13364
# ...

# %%
-Quins són els vols més llargs? I els més endarrerits?
-Etc.

# %%
#vols mes llargs
mes_llargs = df['ActualElapsedTime']
mes_llargs.sort_values(ascending=False).head(10)
# Out:
# 1488690    1114.0
# 1926817     790.0
# 1173580     776.0
# 1367047     750.0
# 1418032     750.0
# 528094      727.0
# 1250037     724.0
# 556381      711.0
# 1926347     702.0
# 363750      698.0
# Name: ActualElapsedTime, dtype: float64

# %%
#més endarrerits
df['temps_delay'] = df['CarrierDelay'] + df['WeatherDelay'] + df['NASDelay'] + df['SecurityDelay'] + df['LateAircraftDelay']
mes_endarrerits = (df.groupby('FlightNum')['temps_delay'].size())
mes_endarrerits.sort_values(ascending=False).head(10)
# Out:
# FlightNum
# 16     1586
# 50     1550
# 40     1507
# 15     1471
# 44     1447
# 52     1410
# 62     1375
# 47     1362
# 321    1355
# 75     1354
# Name: temps_delay, dtype: int64

# %%
- Exercici 3
Exporta el data set net i amb les noves columnes a Excel.

# %%
df.to_csv(r'C:\Users\ab\Itacademy\Pandas\Tasca_5.xlsx', index = False)
